# %% [markdown]
# # Installing Dependencies
#
# To ensure that all the necessary dependencies are installed for this notebook, run the following commands:
#
# !pip install pandas numpy scikit-learn keras matplotlib

# %% [markdown]
# # Importing Dependencies

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing the CSV file into a pandas DataFrame
#
# In this cell, we will import the 'Car_price_cleaned.csv' file into a pandas DataFrame for further analysis.

# %%
# Importing the CSV file into a pandas DataFrame
df = pd.read_csv('Car_price_cleaned.csv')
df.head()
# Out:
#    car_ID  symboling                   CarName  fueltype  aspiration  \
# 0       1          3        alfa-romero giulia         1           0
# 1       2          3       alfa-romero stelvio         1           0
# 2       3          1  alfa-romero Quadrifoglio         1           0
# 3       4          2               audi 100 ls         1           0
# 4       5          2                audi 100ls         1           0
#
#    doornumber  carbody  drivewheel  enginelocation  wheelbase  ...  \
# 0           1        0           2               0  -1.690772  ...
# 1           1        0           2               0  -1.690772  ...
# 2           1        2           2               0  -0.708596  ...
# 3           0        3           1               0   0.173698  ...
# 4           0        3           0               0   0.107110  ...
#
#    curbweight_squared  enginesize_squared  boreratio_squared  stroke_squared  \
# 0             6492304               16900            12.0409          7.1824
# 1             6492304               16900            12.0409          7.1824
# 2             7969329               23104             7.1824         12.0409
# 3             5461569               11881            10.1761         11.5600
# 4             7974976               18496            10.1761         11.5600
#
#    compressionratio_squared  horsepower_squared  peakrpm_squared  \
# 0                      81.0               12321         25000000
# 1                      81.0               12321         25000000
# 2                      81.0               23716         25000000
# 3                     100.0               10404         30250000
# 4                      64.0               13225         30250000
#
#    citympg_squared  highwaympg_squared  log_enginesize
# 0              441                 729        4.875197
# 1              441                 729        4.875197
# 2              361                 676        5.030438
# 3              576                 900        4.700480
# 4              324                 484        4.919981
#
# [5 rows x 43 columns]

# %% [markdown]
# Now we drop the car_ID column which isn't needed and will add noise to our data

# %%
df.drop('car_ID',axis='columns',inplace=True)

# %% [markdown]
# We will stick with only the first part of the CarName as it is the Company that made the car

# %%
# Applying a lambda function to change the CarName to only the first word
df['CarName'] = df['CarName'].apply(lambda x: x.split()[0])
df.head()
# Out:
#    symboling      CarName  fueltype  aspiration  doornumber  carbody  \
# 0          3  alfa-romero         1           0           1        0
# 1          3  alfa-romero         1           0           1        0
# 2          1  alfa-romero         1           0           1        2
# 3          2         audi         1           0           0        3
# 4          2         audi         1           0           0        3
#
#    drivewheel  enginelocation  wheelbase  carlength  ...  curbweight_squared  \
# 0           2               0  -1.690772  -0.426521  ...             6492304
# 1           2               0  -1.690772  -0.426521  ...             6492304
# 2           2               0  -0.708596  -0.231513  ...             7969329
# 3           1               0   0.173698   0.207256  ...             5461569
# 4           0               0   0.107110   0.207256  ...             7974976
#
#    enginesize_squared  boreratio_squared  stroke_squared  \
# 0               16900            12.0409          7.1824
# 1               16900            12.0409          7.1824
# 2               23104             7.1824         12.0409
# 3               11881            10.1761         11.5600
# 4               18496            10.1761         11.5600
#
#    compressionratio_squared  horsepower_squared  peakrpm_squared  \
# 0                      81.0               12321         25000000
# 1                      81.0               12321         25000000
# 2                      81.0               23716         25000000
# 3                     100.0               10404         30250000
# 4                      64.0               13225         30250000
#
#    citympg_squared  highwaympg_squared  log_enginesize
# 0              441                 729        4.875197
# 1              441                 729        4.875197
# 2              361                 676        5.030438
# 3              576                 900        4.700480
# 4              324                 484        4.919981
#
# [5 rows x 42 columns]

# %% [markdown]
# Show the columns to check what data we will input the model and what we want to predict

# %%
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price', 'brand',
#        'model', 'power_to_weight_ratio', 'wheelbase_squared',
#        'carlength_squared', 'carwidth_squared', 'carheight_squared',
#        'curbweight_squared', 'enginesize_squared', 'boreratio_squared',
#        'stroke_squared', 'compressionratio_squared', 'horsepower_squared',
#        'peakrpm_squared', 'citympg_squared', 'highwaympg_squared',
#        'log_enginesize'],
#       dtype='object')

# %% [markdown]
# Our target will be the price of the car and we will remain with all the other data to predict it.

# %%
Target = df['price']
Data = df.drop('price', axis='columns')

# %% [markdown]
# Remember we stick with the first part of the Car Name? Ok, now we will encode them and put it in a column call 'CarName_encoded', models doesn't like strings

# %%
label_encoder = LabelEncoder()

Data['CarName_encoded'] = label_encoder.fit_transform(Data['CarName'])

# %% [markdown]
# Let's see how our Data looks like

# %%
Data.head()
# Out:
#    symboling      CarName  fueltype  aspiration  doornumber  carbody  \
# 0          3  alfa-romero         1           0           1        0
# 1          3  alfa-romero         1           0           1        0
# 2          1  alfa-romero         1           0           1        2
# 3          2         audi         1           0           0        3
# 4          2         audi         1           0           0        3
#
#    drivewheel  enginelocation  wheelbase  carlength  ...  enginesize_squared  \
# 0           2               0  -1.690772  -0.426521  ...               16900
# 1           2               0  -1.690772  -0.426521  ...               16900
# 2           2               0  -0.708596  -0.231513  ...               23104
# 3           1               0   0.173698   0.207256  ...               11881
# 4           0               0   0.107110   0.207256  ...               18496
#
#    boreratio_squared  stroke_squared  compressionratio_squared  \
# 0            12.0409          7.1824                      81.0
# 1            12.0409          7.1824                      81.0
# 2             7.1824         12.0409                      81.0
# 3            10.1761         11.5600                     100.0
# 4            10.1761         11.5600                      64.0
#
#    horsepower_squared  peakrpm_squared  citympg_squared  highwaympg_squared  \
# 0               12321         25000000              441                 729
# 1               12321         25000000              441                 729
# 2               23716         25000000              361                 676
# 3               10404         30250000              576                 900
# 4               13225         30250000              324                 484
#
#    log_enginesize  CarName_encoded
# 0        4.875197                1
# 1        4.875197                1
# 2        5.030438                1
# 3        4.700480                2
# 4        4.919981                2
#
# [5 rows x 42 columns]

# %% [markdown]
# We will define all variables as X (We already drop the price from the Data dataset), instead of using CarName we will use our encoded CarName.

# %%
X=Data[['symboling', 'fueltype', 'aspiration', 'doornumber',
       'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
       'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
       'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
       'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'brand',
       'model', 'power_to_weight_ratio', 'wheelbase_squared',
       'carlength_squared', 'carwidth_squared', 'carheight_squared',
       'curbweight_squared', 'enginesize_squared', 'boreratio_squared',
       'stroke_squared', 'compressionratio_squared', 'horsepower_squared',
       'peakrpm_squared', 'citympg_squared', 'highwaympg_squared',
       'log_enginesize','CarName_encoded']].to_numpy()

# %% [markdown]
# Now we will scale the prices of the cars to make them fit between 0 and 1, this is because models also doesn't really like big large numbers.

# %%
scaler = MinMaxScaler(feature_range=(0,1))
y = scaler.fit_transform(Target.to_numpy().reshape(-1, 1))

# %% [markdown]
# Everything seems alright, let's split our Data (X) and our Prices (y) into train and test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1) # 80% training and 20% test

# %% [markdown]
# Let's see how our Input Train Data Looks like

# %%
X_train
# Out:
# array([[1.00000000e+00, 1.00000000e+00, 0.00000000e+00, ...,
#         6.25000000e+02, 5.20400669e+00, 1.40000000e+01],
#        [1.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         2.50000000e+03, 4.64439090e+00, 1.40000000e+01],
#        [0.00000000e+00, 1.00000000e+00, 0.00000000e+00, ...,
#         9.61000000e+02, 4.69134788e+00, 2.10000000e+01],
#        ...,
#        [3.00000000e+00, 1.00000000e+00, 0.00000000e+00, ...,
#         3.24000000e+02, 5.45958551e+00, 4.00000000e+00],
#        [2.00000000e+00, 1.00000000e+00, 0.00000000e+00, ...,
#         9.61000000e+02, 4.69134788e+00, 2.10000000e+01],
#        [0.00000000e+00, 1.00000000e+00, 0.00000000e+00, ...,
#         1.08900000e+03, 4.70953020e+00, 7.00000000e+00]])

# %% [markdown]
# And now let's see how our Output Train Data looks

# %%
y_train
# Out:
# array([[0.32970061],
#        [0.04917829],
#        [0.12611092],
#        [0.07638648],
#        [0.06655578],
#        [0.88977707],
#        [0.02425401],
#        [0.32351919],
#        [0.20805819],
#        [0.57241448],
#        [0.16836304],
#        [0.48277146],
#        [0.10277543],
#        [0.09252271],
#        [0.02921901],
#        [0.15217715],
#        [0.09252271],
#        [0.21702001],
#        [0.07745395],
#        [0.16699767],
#        [0.14348841],
#        [0.18981183],
#        [0.26393923],
#        [0.06901346],
#        [0.039149  ],
#        [0.05414329],
#        [0.12020257],
#        [0.36197309],
#        [0.16712179],
#        [0.12976019],
#        [0.78849114],
#        [0.25152674],
#        [0.00570975],
#        [0.34337918],
#        [0.75547391],
#        [0.10376843],
#        [0.32833524],
#        [0.29683233],
#        [0.05652649],
#        [0.05538454],
#        [0.06183903],
#        [0.00945832],
#        [0.15964947],
#        [0.09440941],
#        [0.39352564],
#        [0.71769028],
#        [0.23040068],
#        [0.2697731 ],
#        [0.06628271],
#        [0.09510451],
#        [0.08393327],
#        [0.12107145],
#        [0.19418102],
#        [0.39687702],
#        [0.18646045],
#        [0.27009582],
#        [0.07092498],
#        [0.0942977 ],
#        [0.20063552],
#        [0.05404399],
#        [0.10972643],
#        [0.20299389],
#        [0.06901346],
#        [0.29248796],
#        [0.04468497],
#        [0.40631051],
#        [0.01127054],
#        [0.33022194],
#        [0.28263244],
#        [0.01127054],
#        [0.03800705],
#        [0.08383397],
#        [0.28255797],
#        [0.65741522],
#        [0.04644754],
#        [0.09085944],
#        [0.3125962 ],
#        [0.08269202],
#        [0.20795889],
#        [0.06504146],
#        [0.02658756],
#        [0.28739884],
#        [0.32674644],
#        [0.14465518],
#        [0.29112259],
#        [0.10329676],
#        [0.16079142],
#        [0.14721215],
#        [1.        ],
#        [0.04297205],
#        [0.07186833],
#        [0.10329676],
#        [0.43076312],
#        [0.28082022],
#        [0.00697582],
#        [0.24206842],
#        [0.08043295],
#        [0.1099995 ],
#        [0.41954223],
#        [0.07047813],
#        [0.68045281],
#        [0.31629927],
#        [0.12089767],
#        [0.29991063],
#        [0.10865895],
#        [0.25798123],
#        [0.25971898],
#        [0.17804478],
#        [0.15210268],
#        [0.63656224],
#        [0.19430515],
#        [0.11223375],
#        [0.18176853],
#        [0.12017775],
#        [0.0416315 ],
#        [0.06183903],
#        [0.00672757],
#        [0.04138325],
#        [0.02758056],
#        [0.21925426],
#        [0.13852341],
#        [0.76664515],
#        [0.16324909],
#        [0.11858895],
#        [0.20597289],
#        [0.0337868 ],
#        [0.03907452],
#        [0.28578521],
#        [0.26244973],
#        [0.46564222],
#        [0.08383397],
#        [0.79216524],
#        [0.28255797],
#        [0.21168264],
#        [0.03125465],
#        [0.13596644],
#        [0.14093143],
#        [0.34263443],
#        [0.34573755],
#        [0.04984857],
#        [0.07623753],
#        [0.05910829],
#        [0.57420188],
#        [0.00191152],
#        [0.06595998],
#        [0.05163597],
#        [0.04518147],
#        [0.04803634],
#        [0.05821459],
#        [0.20805819],
#        [0.03617   ],
#        [0.28399782],
#        [0.03907452],
#        [0.24631349],
#        [0.72156298],
#        [0.65246264],
#        [0.10215481],
#        [0.21664763],
#        [0.06382503],
#        [0.17506579],
#        [0.33518693],
#        [0.74321037],
#        [0.06169008],
#        [0.06893898]])

# %% [markdown]
# Now we will make our model... I used LSTM as I find out it has better results, but you could use SimpleRNN, or even only a Dense model...
# For SimpleRNN and LSTM (Or GRU) to work, the model needs a three dimensional array so we add the return_sequences to it to make it 3D.
# Our input will be the X_train.shape (Which are the columns that will enter the model), 1 (Which is each row)

# %%
# Define the model
model = Sequential()

# Add a SimpleRNN layer with 50 units
model.add(LSTM(256, input_shape=(X_train.shape[1], 1), return_sequences=True))

model.add(LSTM(128, return_sequences=True))
# Add a Dropout layer with a dropout rate of 0.2
model.add(Dropout(0.2))

model.add(LSTM(64))

model.add(Dense(32))

# Add a Dense layer with one unit for the output
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Print the model summary

# %% [markdown]
# All done! Let's see how our model looks like

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 41, 256)           264192
#
#  lstm_1 (LSTM)               (None, 41, 128)           197120
#
#  dropout (Dropout)           (None, 41, 128)           0
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 512,833
# Trainable params: 512,833
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now we will reshape our X_train... This is because the LSTM layer needs a 3 dimensional array, we will insert as the first dimension the X_train shape[0] (164) and the second dimension will be , X_train shape[1] as the second one (Which is 41) and we will use a third dimension with a 1 in it

# %%
# Reshape X_train to be 3-dimensional as required by the SimpleRNN layer
X_train_reshaped = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))

# %% [markdown]
# ### Checkpoint
# We want our model to save the best approximate to the car prices, so we will include a checkpoint callback

# %%
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, mode='min', save_weights_only=True)

# %% [markdown]
# Now we fit our model with the X_train_reshaped
# We will also use part of the train data as validation (We need this because we are using a checkpoint that works with this data to determine the best model)

# %%
# Fit the model with X_train and y_train
model.fit(X_train_reshaped, y_train, epochs=150, batch_size=32, validation_split=0.2, callbacks=[checkpoint])
# Out:
# Epoch 1/150
# 5/5 [==============================] - 6s 200ms/step - loss: 0.3699 - val_loss: 0.2566
# Epoch 2/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0976 - val_loss: 0.1117
# Epoch 3/150
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0620 - val_loss: 0.0623
# Epoch 4/150
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0552 - val_loss: 0.0542
# Epoch 5/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0430 - val_loss: 0.0698
# Epoch 6/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0564 - val_loss: 0.0512
# Epoch 7/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0396 - val_loss: 0.0616
# Epoch 8/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0448 - val_loss: 0.0523
# Epoch 9/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0372 - val_loss: 0.0499
# Epoch 10/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0377 - val_loss: 0.0494
# Epoch 11/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0377 - val_loss: 0.0499
# Epoch 12/150
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0363 - val_loss: 0.0494
# Epoch 13/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0342 - val_loss: 0.0476
# Epoch 14/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0348 - val_loss: 0.0463
# Epoch 15/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0334 - val_loss: 0.0453
# Epoch 16/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0311 - val_loss: 0.0369
# Epoch 17/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0241 - val_loss: 0.0267
# Epoch 18/150
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0214 - val_loss: 0.0396
# Epoch 19/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0199 - val_loss: 0.0204
# Epoch 20/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0187 - val_loss: 0.0307
# Epoch 21/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0163 - val_loss: 0.0190
# Epoch 22/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0119 - val_loss: 0.0219
# Epoch 23/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0129 - val_loss: 0.0190
# Epoch 24/150
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0107 - val_loss: 0.0185
# Epoch 25/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0084 - val_loss: 0.0206
# Epoch 26/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0078 - val_loss: 0.0201
# Epoch 27/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0146 - val_loss: 0.0382
# Epoch 28/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0159 - val_loss: 0.0206
# Epoch 29/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0154 - val_loss: 0.0329
# Epoch 30/150
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0124 - val_loss: 0.0183
# Epoch 31/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0076 - val_loss: 0.0266
# Epoch 32/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0091 - val_loss: 0.0195
# Epoch 33/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0081 - val_loss: 0.0242
# Epoch 34/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0078 - val_loss: 0.0185
# Epoch 35/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0077 - val_loss: 0.0217
# Epoch 36/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0077 - val_loss: 0.0176
# Epoch 37/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0082 - val_loss: 0.0203
# Epoch 38/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0073 - val_loss: 0.0177
# Epoch 39/150
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0067 - val_loss: 0.0199
# Epoch 40/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0073 - val_loss: 0.0183
# Epoch 41/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0073 - val_loss: 0.0205
# Epoch 42/150
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0075 - val_loss: 0.0171
# Epoch 43/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0074 - val_loss: 0.0228
# Epoch 44/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0071 - val_loss: 0.0176
# Epoch 45/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0079 - val_loss: 0.0288
# Epoch 46/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0102 - val_loss: 0.0172
# Epoch 47/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0067 - val_loss: 0.0207
# Epoch 48/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0063 - val_loss: 0.0178
# Epoch 49/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0070 - val_loss: 0.0166
# Epoch 50/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0155 - val_loss: 0.0256
# Epoch 51/150
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0157 - val_loss: 0.0186
# Epoch 52/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0104 - val_loss: 0.0169
# Epoch 53/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0075 - val_loss: 0.0211
# Epoch 54/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0070 - val_loss: 0.0169
# Epoch 55/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0071 - val_loss: 0.0214
# Epoch 56/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - val_loss: 0.0231
# Epoch 57/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0092 - val_loss: 0.0202
# Epoch 58/150
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0111 - val_loss: 0.0163
# Epoch 59/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0080 - val_loss: 0.0236
# Epoch 60/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0084 - val_loss: 0.0162
# Epoch 61/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0084 - val_loss: 0.0249
# Epoch 62/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0088 - val_loss: 0.0201
# Epoch 63/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0073 - val_loss: 0.0185
# Epoch 64/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0068 - val_loss: 0.0192
# Epoch 65/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0066 - val_loss: 0.0174
# Epoch 66/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0063 - val_loss: 0.0175
# Epoch 67/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0065 - val_loss: 0.0162
# Epoch 68/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0061 - val_loss: 0.0196
# Epoch 69/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0066 - val_loss: 0.0183
# Epoch 70/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0060 - val_loss: 0.0174
# Epoch 71/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0058 - val_loss: 0.0173
# Epoch 72/150
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0063 - val_loss: 0.0158
# Epoch 73/150
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0081 - val_loss: 0.0240
# Epoch 74/150
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0085 - val_loss: 0.0163
# Epoch 75/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0079 - val_loss: 0.0159
# Epoch 76/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0090 - val_loss: 0.0171
# Epoch 77/150
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0071 - val_loss: 0.0150
# Epoch 78/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0071 - val_loss: 0.0182
# Epoch 79/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0063 - val_loss: 0.0164
# Epoch 80/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0066 - val_loss: 0.0176
# Epoch 81/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0064 - val_loss: 0.0157
# Epoch 82/150
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0063 - val_loss: 0.0147
# Epoch 83/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0143 - val_loss: 0.0175
# Epoch 84/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0093 - val_loss: 0.0122
# Epoch 85/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0179 - val_loss: 0.0388
# Epoch 86/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0139 - val_loss: 0.0240
# Epoch 87/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0132 - val_loss: 0.0265
# Epoch 88/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0093 - val_loss: 0.0214
# Epoch 89/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0189 - val_loss: 0.0242
# Epoch 90/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0121 - val_loss: 0.0174
# Epoch 91/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0102 - val_loss: 0.0149
# Epoch 92/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0069 - val_loss: 0.0202
# Epoch 93/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0063 - val_loss: 0.0147
# Epoch 94/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0085 - val_loss: 0.0199
# Epoch 95/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0102 - val_loss: 0.0163
# Epoch 96/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0089 - val_loss: 0.0158
# Epoch 97/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0060 - val_loss: 0.0203
# Epoch 98/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0060 - val_loss: 0.0169
# Epoch 99/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0057 - val_loss: 0.0202
# Epoch 100/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0071 - val_loss: 0.0159
# Epoch 101/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0103 - val_loss: 0.0170
# Epoch 102/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0088 - val_loss: 0.0173
# Epoch 103/150
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0069 - val_loss: 0.0145
# Epoch 104/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0063 - val_loss: 0.0200
# Epoch 105/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0061 - val_loss: 0.0172
# Epoch 106/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0063 - val_loss: 0.0187
# Epoch 107/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0064 - val_loss: 0.0158
# Epoch 108/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0069 - val_loss: 0.0176
# Epoch 109/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0065 - val_loss: 0.0161
# Epoch 110/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0063 - val_loss: 0.0151
# Epoch 111/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0061 - val_loss: 0.0180
# Epoch 112/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0057 - val_loss: 0.0149
# Epoch 113/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0054 - val_loss: 0.0164
# Epoch 114/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0058 - val_loss: 0.0166
# Epoch 115/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0056 - val_loss: 0.0170
# Epoch 116/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0054 - val_loss: 0.0153
# Epoch 117/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0056 - val_loss: 0.0157
# Epoch 118/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0048 - val_loss: 0.0145
# Epoch 119/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0057 - val_loss: 0.0147
# Epoch 120/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0053 - val_loss: 0.0141
# Epoch 121/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0052 - val_loss: 0.0146
# Epoch 122/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0049 - val_loss: 0.0141
# Epoch 123/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0048 - val_loss: 0.0134
# Epoch 124/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0061 - val_loss: 0.0169
# Epoch 125/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0057 - val_loss: 0.0147
# Epoch 126/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0143
# Epoch 127/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0051 - val_loss: 0.0143
# Epoch 128/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0054 - val_loss: 0.0144
# Epoch 129/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0056 - val_loss: 0.0145
# Epoch 130/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0049 - val_loss: 0.0130
# Epoch 131/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0048 - val_loss: 0.0140
# Epoch 132/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0048 - val_loss: 0.0126
# Epoch 133/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0047 - val_loss: 0.0193
# Epoch 134/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0078 - val_loss: 0.0126
# Epoch 135/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0062 - val_loss: 0.0166
# Epoch 136/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0065 - val_loss: 0.0145
# Epoch 137/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0056 - val_loss: 0.0146
# Epoch 138/150
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0048 - val_loss: 0.0138
# Epoch 139/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0048 - val_loss: 0.0134
# Epoch 140/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 0.0124
# Epoch 141/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0048 - val_loss: 0.0121
# Epoch 142/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0043 - val_loss: 0.0116
# Epoch 143/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0058 - val_loss: 0.0187
# Epoch 144/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0083 - val_loss: 0.0132
# Epoch 145/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0120 - val_loss: 0.0219
# Epoch 146/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0115 - val_loss: 0.0138
# Epoch 147/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0076 - val_loss: 0.0137
# Epoch 148/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0057 - val_loss: 0.0174
# Epoch 149/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0052 - val_loss: 0.0136
# Epoch 150/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0061 - val_loss: 0.0165

# %% [markdown]
# Ok, everything seems alright! Now let's try our new model, first we will reshape our test data

# %%
# Reshape X_test to be 3-dimensional as required by the SimpleRNN layer
X_test_reshaped = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# Now let's evaluate our model, we will use our reshaped test data and the y_test

# %%
# Evaluate the model
loss = model.evaluate(X_test_reshaped, y_test)

print(f'Model Loss on Test Data: {loss}')
# Out:
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0048
# Model Loss on Test Data: 0.004842610564082861

# %% [markdown]
# We have a loss of 0.004842610564082861 seems to be alright, let's try prediting all the inputs and let's see what differences do we have between our predicted value and the real value of our test data.

# %%
# Predict a single value from y_test
y_pred = model.predict(X_test_reshaped)

# Inverse transform the predicted value to its original form
y_pred_original = scaler.inverse_transform(y_pred)
y_test_original = scaler.inverse_transform(y_test)
# Out:
# 2/2 [==============================] - 1s 3ms/step

# %% [markdown]
# #### Graph
# Let's see it in an old fashion style.

# %%
# Plotting the differences between y_pred_original and y_test_original
plt.figure(figsize=(10, 6))
plt.plot(y_test_original, label='Actual Price')
plt.plot(y_pred_original, label='Predicted Price')
plt.xlabel('Sample Index')
plt.ylabel('Price')
plt.title('Actual vs Predicted Car Prices')
plt.legend()
plt.show()

# %% [markdown]
# #### We finish our model, as you can see, it predicts very well the price of the cars using the info we input to it.
