# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score
import lightgbm as lgb
import optuna
from optuna.integration import LightGBMTunerCV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
import tensorflow_decision_forests as tfdf
import tensorflow as tf
# Out:
# 2024-10-18 02:34:04.751844: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-18 02:34:04.789736: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-18 02:34:04.810545: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-18 02:34:04.825828: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-18 02:34:04.843081: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df = pd.read_csv('RNNs/Tensorflow-Keras/Binary Classification/train.csv')
df_test = pd.read_csv('RNNs/Tensorflow-Keras/Binary Classification/test.csv')

# %%
label_encoder = LabelEncoder()

# Columns to be label encoded
columns_to_encode = ['person_home_ownership', 'loan_intent', 'loan_grade', 'cb_person_default_on_file']

# Apply label encoding to each specified column
for column in columns_to_encode:
    df[f'{column}_encoded'] = label_encoder.fit_transform(df[column])
    df_test[f'{column}_encoded'] = label_encoder.fit_transform(df_test[column])
# Display the first few rows of the dataframe to verify the changes
df.head()
# Out:
#    id  person_age  person_income person_home_ownership  person_emp_length  \
# 0   0          37          35000                  RENT                0.0
# 1   1          22          56000                   OWN                6.0
# 2   2          29          28800                   OWN                8.0
# 3   3          30          70000                  RENT               14.0
# 4   4          22          60000                  RENT                2.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 0   EDUCATION          B       6000          11.49                 0.17
# 1     MEDICAL          C       4000          13.35                 0.07
# 2    PERSONAL          A       6000           8.90                 0.21
# 3     VENTURE          B      12000          11.11                 0.17
# 4     MEDICAL          A       6000           6.92                 0.10
#
#   cb_person_default_on_file  cb_person_cred_hist_length  loan_status  \
# 0                         N                          14            0
# 1                         N                           2            0
# 2                         N                          10            0
# 3                         N                           5            0
# 4                         N                           3            0
#
#    person_home_ownership_encoded  loan_intent_encoded  loan_grade_encoded  \
# 0                              3                    1                   1
# 1                              2                    3                   2
# 2                              2                    4                   0
# 3                              3                    5                   1
# 4                              3                    3                   0
#
#    cb_person_default_on_file_encoded
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0

# %%
features = ['person_age', 'person_income', 'person_emp_length', 'loan_amnt', 'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length', 'person_home_ownership_encoded', 'loan_intent_encoded', 'loan_grade_encoded', 'cb_person_default_on_file_encoded']
label = 'loan_status'

# %%
# Define the parameter grid for XGBoost
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7, 10],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0]
}

# Initialize the XGBoost classifier
xgb_clf = xgb.XGBClassifier(objective='binary:logistic', random_state=42)

# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=xgb_clf, param_distributions=param_grid, n_iter=50, scoring='accuracy', cv=3, verbose=1, random_state=42, n_jobs=-1)

# Fit RandomizedSearchCV
random_search.fit(df[features], df[label])

# Get the best estimator
best_xgb_clf = random_search.best_estimator_

# Make predictions on the test dataset
xgb_predictions = best_xgb_clf.predict(df_test[features])

# Add the predictions to the test dataframe
df_test['xgb_predicted_loan_status'] = xgb_predictions

# Display the first few rows of the test dataframe to verify the predictions
df_test.head()
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
#       id  person_age  person_income person_home_ownership  person_emp_length  \
# 0  58645          23          69000                  RENT                3.0
# 1  58646          26          96000              MORTGAGE                6.0
# 2  58647          26          30000                  RENT                5.0
# 3  58648          33          50000                  RENT                4.0
# 4  58649          26         102000              MORTGAGE                8.0
#
#          loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0    HOMEIMPROVEMENT          F      25000          15.76
# 1           PERSONAL          C      10000          12.68
# 2            VENTURE          E       4000          17.19
# 3  DEBTCONSOLIDATION          A       7000           8.90
# 4    HOMEIMPROVEMENT          D      15000          16.32
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length  \
# 0                 0.36                         N                           2
# 1                 0.10                         Y                           4
# 2                 0.13                         Y                           2
# 3                 0.14                         N                           7
# 4                 0.15                         Y                           4
#
#    person_home_ownership_encoded  loan_intent_encoded  loan_grade_encoded  \
# 0                              3                    2                   5
# 1                              0                    4                   2
# 2                              3                    5                   4
# 3                              3                    0                   0
# 4                              0                    2                   3
#
#    cb_person_default_on_file_encoded  xgb_predicted_loan_status
# 0                                  0                          1
# 1                                  1                          0
# 2                                  1                          1
# 3                                  0                          0
# 4                                  1                          0

# %%
# Define the dataset for LightGBM
train_data = lgb.Dataset(df[features], label=df[label])

# Define the parameter search space
param_grid = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'boosting_type': 'gbdt',
    'verbosity': -1,
    'n_jobs': -1,
    'seed': 42
}

# Define the tuning function
def objective(trial):
    params = {
        'num_leaves': trial.suggest_int('num_leaves', 20, 150),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'verbosity': -1
    }
    
    cv_results = lgb.cv(
        params,
        train_data,
        nfold=3,
        stratified=True,
        shuffle=True,
        metrics='binary_logloss',
        seed=42,
        eval_train_metric=True,
    )
    return min(cv_results['train binary_logloss-mean'])

# Create the study and optimize
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

# Get the best parameters
best_params = study.best_params
best_params.update(param_grid)

# Train the final model with the best parameters
lgb_clf = lgb.LGBMClassifier(**best_params)
lgb_clf.fit(df[features], df[label])

# Make predictions on the test dataset
lgb_predictions = lgb_clf.predict(df_test[features])

# Add the predictions to the test dataframe
df_test['lgb_predicted_loan_status'] = lgb_predictions

# Display the first few rows of the test dataframe to verify the predictions
df_test.head()
# Out:
# [I 2024-10-18 02:34:36,551] A new study created in memory with name: no-name-7f8935f3-07f4-4b56-940c-2698b5dd7689
# [I 2024-10-18 02:34:49,300] Trial 0 finished with value: 0.14873660272354394 and parameters: {'num_leaves': 123, 'max_depth': 6, 'learning_rate': 0.0118209867778185, 'n_estimators': 415, 'subsample': 0.9234400859227202, 'colsample_bytree': 0.7019559781182263, 'min_child_weight': 2}. Best is trial 0 with value: 0.14873660272354394.
# [I 2024-10-18 02:35:00,460] Trial 1 finished with value: 0.24446176308038403 and parameters: {'num_leaves': 125, 'max_depth': 9, 'learning_rate': 0.001258782905216087, 'n_estimators': 486, 'subsample': 0.8379989062243944, 'colsample_bytree': 0.9973442290534018, 'min_child_weight': 6}. Best is trial 0 with value: 0.14873660272354394.
# [I 2024-10-18 02:35:05,511] Trial 2 finished with value: 0.0959313035259561 and parameters: {'num_leaves': 21, 'max_depth': 15, 'learning_rate': 0.08338574320176234, 'n_estimators': 780, 'subsample': 0.7286264220443686, 'colsample_bytree': 0.9545562337447302, 'min_child_weight': 5}. Best is trial 2 with value: 0.0959313035259561.
# [I 2024-10-18 02:35:18,075] Trial 3 finished with value: 0.22338766380501526 and parameters: {'num_leaves': 61, 'max_depth': 14, 'learning_rate': 0.0010642836029843216, 'n_estimators': 805, 'subsample': 0.9467308536616255, 'colsample_bytree': 0.8891642066879373, 'min_child_weight': 2}. Best is trial 2 with value: 0.0959313035259561.
# [I 2024-10-18 02:35:22,789] Trial 4 finished with value: 0.20628531040717168 and parameters: {'num_leaves': 37, 'max_depth': 5, 'learning_rate': 0.002548956117080752, 'n_estimators': 580, 'subsample': 0.761041306124337, 'colsample_bytree': 0.844573870649626, 'min_child_weight': 3}. Best is trial 2 with value: 0.0959313035259561.
# [I 2024-10-18 02:35:25,558] Trial 5 finished with value: 0.27280244112683966 and parameters: {'num_leaves': 93, 'max_depth': 8, 'learning_rate': 0.0030984733502504944, 'n_estimators': 175, 'subsample': 0.6427722990483872, 'colsample_bytree': 0.6757304290845756, 'min_child_weight': 2}. Best is trial 2 with value: 0.0959313035259561.
# [I 2024-10-18 02:35:33,393] Trial 6 finished with value: 0.12582241819334963 and parameters: {'num_leaves': 94, 'max_depth': 7, 'learning_rate': 0.025266760487602024, 'n_estimators': 329, 'subsample': 0.9134379538730482, 'colsample_bytree': 0.783087448688798, 'min_child_weight': 5}. Best is trial 2 with value: 0.0959313035259561.
# [I 2024-10-18 02:35:39,908] Trial 7 finished with value: 0.13346034715179836 and parameters: {'num_leaves': 46, 'max_depth': 5, 'learning_rate': 0.0216553882720947, 'n_estimators': 823, 'subsample': 0.9722261711850361, 'colsample_bytree': 0.9940704751040044, 'min_child_weight': 2}. Best is trial 2 with value: 0.0959313035259561.
# [I 2024-10-18 02:35:54,199] Trial 8 finished with value: 0.12253136508354623 and parameters: {'num_leaves': 80, 'max_depth': 12, 'learning_rate': 0.006466438816351948, 'n_estimators': 915, 'subsample': 0.6627975451841621, 'colsample_bytree': 0.8111229505971113, 'min_child_weight': 6}. Best is trial 2 with value: 0.0959313035259561.
# [I 2024-10-18 02:36:15,757] Trial 9 finished with value: 0.20738366016316556 and parameters: {'num_leaves': 136, 'max_depth': 9, 'learning_rate': 0.0010582982447915996, 'n_estimators': 938, 'subsample': 0.8726018713091934, 'colsample_bytree': 0.8920221049867294, 'min_child_weight': 9}. Best is trial 2 with value: 0.0959313035259561.
# [I 2024-10-18 02:36:20,615] Trial 10 finished with value: 0.09863267559527163 and parameters: {'num_leaves': 27, 'max_depth': 15, 'learning_rate': 0.06757926079965733, 'n_estimators': 659, 'subsample': 0.7347301803036582, 'colsample_bytree': 0.9294145501872266, 'min_child_weight': 10}. Best is trial 2 with value: 0.0959313035259561.
# [I 2024-10-18 02:36:25,036] Trial 11 finished with value: 0.09534437952119908 and parameters: {'num_leaves': 22, 'max_depth': 15, 'learning_rate': 0.09635691427298551, 'n_estimators': 659, 'subsample': 0.7444157071752696, 'colsample_bytree': 0.9342886186012965, 'min_child_weight': 10}. Best is trial 11 with value: 0.09534437952119908.
# [I 2024-10-18 02:36:29,310] Trial 12 finished with value: 0.10708660980820998 and parameters: {'num_leaves': 20, 'max_depth': 12, 'learning_rate': 0.07918525959600048, 'n_estimators': 700, 'subsample': 0.7107269128384581, 'colsample_bytree': 0.6030241528937637, 'min_child_weight': 8}. Best is trial 11 with value: 0.09534437952119908.
# [I 2024-10-18 02:36:37,445] Trial 13 finished with value: 0.08514739647141538 and parameters: {'num_leaves': 58, 'max_depth': 12, 'learning_rate': 0.04289123814076644, 'n_estimators': 738, 'subsample': 0.7907986942020185, 'colsample_bytree': 0.9358961621635928, 'min_child_weight': 4}. Best is trial 13 with value: 0.08514739647141538.
# [I 2024-10-18 02:36:44,338] Trial 14 finished with value: 0.09413570740732709 and parameters: {'num_leaves': 60, 'max_depth': 12, 'learning_rate': 0.03949361727568925, 'n_estimators': 570, 'subsample': 0.7989093102866072, 'colsample_bytree': 0.875443872945914, 'min_child_weight': 7}. Best is trial 13 with value: 0.08514739647141538.
# [I 2024-10-18 02:36:51,906] Trial 15 finished with value: 0.09451999494615533 and parameters: {'num_leaves': 64, 'max_depth': 12, 'learning_rate': 0.03857744382832227, 'n_estimators': 567, 'subsample': 0.8116823157193002, 'colsample_bytree': 0.8555512203160829, 'min_child_weight': 7}. Best is trial 13 with value: 0.08514739647141538.
# [I 2024-10-18 02:36:53,483] Trial 16 finished with value: 0.1746994706643641 and parameters: {'num_leaves': 64, 'max_depth': 3, 'learning_rate': 0.03824052620427626, 'n_estimators': 333, 'subsample': 0.7943340545694917, 'colsample_bytree': 0.7988677623383409, 'min_child_weight': 4}. Best is trial 13 with value: 0.08514739647141538.
# [I 2024-10-18 02:36:55,794] Trial 17 finished with value: 0.18661295130805533 and parameters: {'num_leaves': 79, 'max_depth': 11, 'learning_rate': 0.011619252857377499, 'n_estimators': 131, 'subsample': 0.8717786853870517, 'colsample_bytree': 0.7304661141548994, 'min_child_weight': 7}. Best is trial 13 with value: 0.08514739647141538.
# [I 2024-10-18 02:37:04,758] Trial 18 finished with value: 0.1086647472590449 and parameters: {'num_leaves': 44, 'max_depth': 10, 'learning_rate': 0.043592172436275965, 'n_estimators': 432, 'subsample': 0.6007798975629434, 'colsample_bytree': 0.8921342906669513, 'min_child_weight': 4}. Best is trial 13 with value: 0.08514739647141538.
# [I 2024-10-18 02:37:13,710] Trial 19 finished with value: 0.1058934733094512 and parameters: {'num_leaves': 56, 'max_depth': 13, 'learning_rate': 0.020849470526887508, 'n_estimators': 731, 'subsample': 0.7869566204372602, 'colsample_bytree': 0.9514984264260113, 'min_child_weight': 8}. Best is trial 13 with value: 0.08514739647141538.
# [I 2024-10-18 02:37:25,102] Trial 20 finished with value: 0.13181691736443 and parameters: {'num_leaves': 109, 'max_depth': 10, 'learning_rate': 0.00637300558606176, 'n_estimators': 596, 'subsample': 0.842256695745062, 'colsample_bytree': 0.8470778447559026, 'min_child_weight': 4}. Best is trial 13 with value: 0.08514739647141538.
# [I 2024-10-18 02:37:32,649] Trial 21 finished with value: 0.09223193012022612 and parameters: {'num_leaves': 69, 'max_depth': 13, 'learning_rate': 0.03898581326890198, 'n_estimators': 543, 'subsample': 0.8239995652462941, 'colsample_bytree': 0.8526024745779042, 'min_child_weight': 7}. Best is trial 13 with value: 0.08514739647141538.
# [I 2024-10-18 02:37:39,751] Trial 22 finished with value: 0.08627450590000403 and parameters: {'num_leaves': 76, 'max_depth': 13, 'learning_rate': 0.05042645775176479, 'n_estimators': 503, 'subsample': 0.8281779641988035, 'colsample_bytree': 0.7587098922215989, 'min_child_weight': 7}. Best is trial 13 with value: 0.08514739647141538.
# [I 2024-10-18 02:37:46,416] Trial 23 finished with value: 0.08435480669225161 and parameters: {'num_leaves': 76, 'max_depth': 13, 'learning_rate': 0.05614803156879675, 'n_estimators': 479, 'subsample': 0.8780926639354378, 'colsample_bytree': 0.7535807643879473, 'min_child_weight': 6}. Best is trial 23 with value: 0.08435480669225161.
# [I 2024-10-18 02:37:51,035] Trial 24 finished with value: 0.09041534530270291 and parameters: {'num_leaves': 92, 'max_depth': 14, 'learning_rate': 0.0627476282388927, 'n_estimators': 284, 'subsample': 0.8756248342643098, 'colsample_bytree': 0.739278566889945, 'min_child_weight': 5}. Best is trial 23 with value: 0.08435480669225161.
# [I 2024-10-18 02:38:01,019] Trial 25 finished with value: 0.10966366216112867 and parameters: {'num_leaves': 105, 'max_depth': 13, 'learning_rate': 0.016789407862081194, 'n_estimators': 466, 'subsample': 0.8608180058587686, 'colsample_bytree': 0.7652458629979035, 'min_child_weight': 6}. Best is trial 23 with value: 0.08435480669225161.
# [I 2024-10-18 02:38:06,893] Trial 26 finished with value: 0.09540675141481007 and parameters: {'num_leaves': 77, 'max_depth': 11, 'learning_rate': 0.05582820232755824, 'n_estimators': 376, 'subsample': 0.8973238378401532, 'colsample_bytree': 0.669489565778272, 'min_child_weight': 1}. Best is trial 23 with value: 0.08435480669225161.
# [I 2024-10-18 02:38:09,987] Trial 27 finished with value: 0.13557913878584774 and parameters: {'num_leaves': 50, 'max_depth': 14, 'learning_rate': 0.024145244278772033, 'n_estimators': 241, 'subsample': 0.7786256459312411, 'colsample_bytree': 0.7498287397926457, 'min_child_weight': 8}. Best is trial 23 with value: 0.08435480669225161.
# [I 2024-10-18 02:38:17,168] Trial 28 finished with value: 0.10455344044987465 and parameters: {'num_leaves': 72, 'max_depth': 11, 'learning_rate': 0.028704654211706877, 'n_estimators': 507, 'subsample': 0.9788503681290333, 'colsample_bytree': 0.7051257760944796, 'min_child_weight': 3}. Best is trial 23 with value: 0.08435480669225161.
# [I 2024-10-18 02:38:26,237] Trial 29 finished with value: 0.14798867453655248 and parameters: {'num_leaves': 106, 'max_depth': 13, 'learning_rate': 0.007127651771281475, 'n_estimators': 404, 'subsample': 0.9426277325485861, 'colsample_bytree': 0.6386342133160925, 'min_child_weight': 3}. Best is trial 23 with value: 0.08435480669225161.
# [I 2024-10-18 02:38:38,573] Trial 30 finished with value: 0.06813688477930911 and parameters: {'num_leaves': 87, 'max_depth': 10, 'learning_rate': 0.05497501751019136, 'n_estimators': 852, 'subsample': 0.6956190375692668, 'colsample_bytree': 0.8159072649426115, 'min_child_weight': 6}. Best is trial 30 with value: 0.06813688477930911.
# [I 2024-10-18 02:38:50,962] Trial 31 finished with value: 0.06849497114579806 and parameters: {'num_leaves': 90, 'max_depth': 10, 'learning_rate': 0.053158924880234305, 'n_estimators': 859, 'subsample': 0.6983707614779912, 'colsample_bytree': 0.818683118768487, 'min_child_weight': 6}. Best is trial 30 with value: 0.06813688477930911.
# [I 2024-10-18 02:39:05,098] Trial 32 finished with value: 0.048712241584237814 and parameters: {'num_leaves': 87, 'max_depth': 9, 'learning_rate': 0.09842172834108016, 'n_estimators': 989, 'subsample': 0.6924149209282144, 'colsample_bytree': 0.8233480854271018, 'min_child_weight': 6}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:39:16,008] Trial 33 finished with value: 0.058663440729348315 and parameters: {'num_leaves': 88, 'max_depth': 8, 'learning_rate': 0.09827300997995604, 'n_estimators': 876, 'subsample': 0.6920689020612957, 'colsample_bytree': 0.8188883671528792, 'min_child_weight': 6}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:39:27,385] Trial 34 finished with value: 0.06200748003256052 and parameters: {'num_leaves': 116, 'max_depth': 8, 'learning_rate': 0.08877246294780904, 'n_estimators': 863, 'subsample': 0.6953045699073207, 'colsample_bytree': 0.8170192249809146, 'min_child_weight': 5}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:39:55,382] Trial 35 finished with value: 0.05346351358931898 and parameters: {'num_leaves': 118, 'max_depth': 8, 'learning_rate': 0.09842132736995289, 'n_estimators': 996, 'subsample': 0.6659273580091146, 'colsample_bytree': 0.7853860743915851, 'min_child_weight': 5}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:40:11,772] Trial 36 finished with value: 0.06972829721882019 and parameters: {'num_leaves': 122, 'max_depth': 7, 'learning_rate': 0.08652427027287819, 'n_estimators': 993, 'subsample': 0.6625188452193036, 'colsample_bytree': 0.7924376173675728, 'min_child_weight': 5}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:40:23,047] Trial 37 finished with value: 0.06637351584138008 and parameters: {'num_leaves': 118, 'max_depth': 7, 'learning_rate': 0.09906462057999849, 'n_estimators': 985, 'subsample': 0.6248533597022954, 'colsample_bytree': 0.8349873702100461, 'min_child_weight': 4}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:40:43,345] Trial 38 finished with value: 0.06475022638233101 and parameters: {'num_leaves': 147, 'max_depth': 8, 'learning_rate': 0.0741978691898927, 'n_estimators': 924, 'subsample': 0.6772818325487253, 'colsample_bytree': 0.7790318381534698, 'min_child_weight': 5}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:41:06,306] Trial 39 finished with value: 0.1735367790695391 and parameters: {'num_leaves': 134, 'max_depth': 8, 'learning_rate': 0.0017972443792978702, 'n_estimators': 958, 'subsample': 0.6343078474456381, 'colsample_bytree': 0.8643881647709117, 'min_child_weight': 5}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:41:14,526] Trial 40 finished with value: 0.09057860251963874 and parameters: {'num_leaves': 100, 'max_depth': 6, 'learning_rate': 0.07622377069872516, 'n_estimators': 891, 'subsample': 0.7181864704502238, 'colsample_bytree': 0.8305031670981675, 'min_child_weight': 3}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:41:26,611] Trial 41 finished with value: 0.06678263220543662 and parameters: {'num_leaves': 143, 'max_depth': 8, 'learning_rate': 0.07288552554392443, 'n_estimators': 898, 'subsample': 0.6719384916816825, 'colsample_bytree': 0.7731775033051975, 'min_child_weight': 5}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:41:40,384] Trial 42 finished with value: 0.054710865490119776 and parameters: {'num_leaves': 115, 'max_depth': 9, 'learning_rate': 0.08903236178446085, 'n_estimators': 806, 'subsample': 0.6792163385650114, 'colsample_bytree': 0.7874719760464608, 'min_child_weight': 5}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:41:53,123] Trial 43 finished with value: 0.0521582855324407 and parameters: {'num_leaves': 115, 'max_depth': 9, 'learning_rate': 0.09810309097164036, 'n_estimators': 788, 'subsample': 0.7461808670512207, 'colsample_bytree': 0.8016424739813052, 'min_child_weight': 6}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:42:05,674] Trial 44 finished with value: 0.052998406930372506 and parameters: {'num_leaves': 127, 'max_depth': 9, 'learning_rate': 0.09327093670558194, 'n_estimators': 768, 'subsample': 0.759822607600629, 'colsample_bytree': 0.792190482392077, 'min_child_weight': 6}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:42:19,693] Trial 45 finished with value: 0.08679701245387712 and parameters: {'num_leaves': 130, 'max_depth': 9, 'learning_rate': 0.02979992182782301, 'n_estimators': 787, 'subsample': 0.7642710566383022, 'colsample_bytree': 0.7870206033172156, 'min_child_weight': 6}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:42:33,266] Trial 46 finished with value: 0.06658477635592497 and parameters: {'num_leaves': 114, 'max_depth': 9, 'learning_rate': 0.06442927943278376, 'n_estimators': 815, 'subsample': 0.7533652825387769, 'colsample_bytree': 0.7202210675942378, 'min_child_weight': 7}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:42:44,538] Trial 47 finished with value: 0.056876843565126456 and parameters: {'num_leaves': 127, 'max_depth': 9, 'learning_rate': 0.09979691289016103, 'n_estimators': 627, 'subsample': 0.6455611815612322, 'colsample_bytree': 0.9079678422518043, 'min_child_weight': 8}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:42:52,035] Trial 48 finished with value: 0.09708651613448065 and parameters: {'num_leaves': 139, 'max_depth': 6, 'learning_rate': 0.06827932752569212, 'n_estimators': 769, 'subsample': 0.7374755381753385, 'colsample_bytree': 0.8013265952113129, 'min_child_weight': 6}. Best is trial 32 with value: 0.048712241584237814.
# [I 2024-10-18 02:43:00,441] Trial 49 finished with value: 0.08363962705331633 and parameters: {'num_leaves': 98, 'max_depth': 7, 'learning_rate': 0.07863333528981083, 'n_estimators': 687, 'subsample': 0.7290063224921957, 'colsample_bytree': 0.8342508420447486, 'min_child_weight': 5}. Best is trial 32 with value: 0.048712241584237814.
#       id  person_age  person_income person_home_ownership  person_emp_length  \
# 0  58645          23          69000                  RENT                3.0
# 1  58646          26          96000              MORTGAGE                6.0
# 2  58647          26          30000                  RENT                5.0
# 3  58648          33          50000                  RENT                4.0
# 4  58649          26         102000              MORTGAGE                8.0
#
#          loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0    HOMEIMPROVEMENT          F      25000          15.76
# 1           PERSONAL          C      10000          12.68
# 2            VENTURE          E       4000          17.19
# 3  DEBTCONSOLIDATION          A       7000           8.90
# 4    HOMEIMPROVEMENT          D      15000          16.32
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length  \
# 0                 0.36                         N                           2
# 1                 0.10                         Y                           4
# 2                 0.13                         Y                           2
# 3                 0.14                         N                           7
# 4                 0.15                         Y                           4
#
#    person_home_ownership_encoded  loan_intent_encoded  loan_grade_encoded  \
# 0                              3                    2                   5
# 1                              0                    4                   2
# 2                              3                    5                   4
# 3                              3                    0                   0
# 4                              0                    2                   3
#
#    cb_person_default_on_file_encoded  xgb_predicted_loan_status  \
# 0                                  0                          1
# 1                                  1                          0
# 2                                  1                          1
# 3                                  0                          0
# 4                                  1                          0
#
#    lgb_predicted_loan_status
# 0                          1
# 1                          0
# 2                          1
# 3                          0
# 4                          0

# %%
# Define the parameter grid for Logistic Regression
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2', 'elasticnet', 'none'],
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'max_iter': [100, 200, 300, 500, 1000]
}

# Initialize the Logistic Regression classifier
log_reg = LogisticRegression(random_state=42)

# Initialize RandomizedSearchCV
random_search_log_reg = RandomizedSearchCV(estimator=log_reg, param_distributions=param_grid, n_iter=50, scoring='accuracy', cv=3, verbose=1, random_state=42, n_jobs=-1)

# Fit RandomizedSearchCV
random_search_log_reg.fit(df[features], df[label])

# Get the best estimator
best_log_reg = random_search_log_reg.best_estimator_

# Make predictions on the test dataset
log_reg_predictions = best_log_reg.predict(df_test[features])

# Add the predictions to the test dataframe
df_test['log_reg_predicted_loan_status'] = log_reg_predictions

# Display the first few rows of the test dataframe to verify the predictions
df_test.head()
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/optimize.py:99: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
#       id  person_age  person_income person_home_ownership  person_emp_length  \
# 0  58645          23          69000                  RENT                3.0
# 1  58646          26          96000              MORTGAGE                6.0
# 2  58647          26          30000                  RENT                5.0
# 3  58648          33          50000                  RENT                4.0
# 4  58649          26         102000              MORTGAGE                8.0
#
#          loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0    HOMEIMPROVEMENT          F      25000          15.76
# 1           PERSONAL          C      10000          12.68
# 2            VENTURE          E       4000          17.19
# 3  DEBTCONSOLIDATION          A       7000           8.90
# 4    HOMEIMPROVEMENT          D      15000          16.32
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length  \
# 0                 0.36                         N                           2
# 1                 0.10                         Y                           4
# 2                 0.13                         Y                           2
# 3                 0.14                         N                           7
# 4                 0.15                         Y                           4
#
#    person_home_ownership_encoded  loan_intent_encoded  loan_grade_encoded  \
# 0                              3                    2                   5
# 1                              0                    4                   2
# 2                              3                    5                   4
# 3                              3                    0                   0
# 4                              0                    2                   3
#
#    cb_person_default_on_file_encoded  xgb_predicted_loan_status  \
# 0                                  0                          1
# 1                                  1                          0
# 2                                  1                          1
# 3                                  0                          0
# 4                                  1                          0
#
#    lgb_predicted_loan_status  log_reg_predicted_loan_status
# 0                          1                              1
# 1                          0                              0
# 2                          1                              1
# 3                          0                              0
# 4                          0                              0

# %%
# Define the parameter grid for Decision Tree
param_grid = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [None, 'auto', 'sqrt', 'log2']
}

# Initialize the Decision Tree classifier
dt_clf = DecisionTreeClassifier(random_state=42)

# Initialize RandomizedSearchCV
random_search_dt = RandomizedSearchCV(estimator=dt_clf, param_distributions=param_grid, n_iter=50, scoring='accuracy', cv=3, verbose=1, random_state=42, n_jobs=-1)

# Fit RandomizedSearchCV
random_search_dt.fit(df[features], df[label])

# Get the best estimator
best_dt_clf = random_search_dt.best_estimator_

# Make predictions on the test dataset
dt_predictions = best_dt_clf.predict(df_test[features])

# Add the predictions to the test dataframe
df_test['dt_predicted_loan_status'] = dt_predictions

# Display the first few rows of the test dataframe to verify the predictions
df_test.head()
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
#       id  person_age  person_income person_home_ownership  person_emp_length  \
# 0  58645          23          69000                  RENT                3.0
# 1  58646          26          96000              MORTGAGE                6.0
# 2  58647          26          30000                  RENT                5.0
# 3  58648          33          50000                  RENT                4.0
# 4  58649          26         102000              MORTGAGE                8.0
#
#          loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0    HOMEIMPROVEMENT          F      25000          15.76
# 1           PERSONAL          C      10000          12.68
# 2            VENTURE          E       4000          17.19
# 3  DEBTCONSOLIDATION          A       7000           8.90
# 4    HOMEIMPROVEMENT          D      15000          16.32
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length  \
# 0                 0.36                         N                           2
# 1                 0.10                         Y                           4
# 2                 0.13                         Y                           2
# 3                 0.14                         N                           7
# 4                 0.15                         Y                           4
#
#    person_home_ownership_encoded  loan_intent_encoded  loan_grade_encoded  \
# 0                              3                    2                   5
# 1                              0                    4                   2
# 2                              3                    5                   4
# 3                              3                    0                   0
# 4                              0                    2                   3
#
#    cb_person_default_on_file_encoded  xgb_predicted_loan_status  \
# 0                                  0                          1
# 1                                  1                          0
# 2                                  1                          1
# 3                                  0                          0
# 4                                  1                          0
#
#    lgb_predicted_loan_status  log_reg_predicted_loan_status  \
# 0                          1                              1
# 1                          0                              0
# 2                          1                              1
# 3                          0                              0
# 4                          0                              0
#
#    dt_predicted_loan_status
# 0                         1
# 1                         0
# 2                         0
# 3                         0
# 4                         0

# %%
df_test[['id', 'xgb_predicted_loan_status']].to_csv('RNNs/Tensorflow-Keras/Binary Classification/XGB_predictions.csv', index=False)
df_test[['id', 'lgb_predicted_loan_status']].to_csv('RNNs/Tensorflow-Keras/Binary Classification/LGB_predictions.csv', index=False)
df_test[['id', 'log_reg_predicted_loan_status']].to_csv('RNNs/Tensorflow-Keras/Binary Classification/LogReg_predictions.csv', index=False)
df_test[['id', 'dt_predicted_loan_status']].to_csv('RNNs/Tensorflow-Keras/Binary Classification/DT_predictions.csv', index=False)

# %%
# Create a pool of all predicted loan statuses
df_test['pooled_predicted_loan_status'] = df_test[['xgb_predicted_loan_status', 'lgb_predicted_loan_status', 'log_reg_predicted_loan_status', 'dt_predicted_loan_status']].mode(axis=1)[0]
df_test['pooled_predicted_loan_status'] = df_test['pooled_predicted_loan_status'].astype(int)
# Display the first few rows of the test dataframe to verify the pooled predictions
df_test.head()
# Out:
#       id  person_age  person_income person_home_ownership  person_emp_length  \
# 0  58645          23          69000                  RENT                3.0
# 1  58646          26          96000              MORTGAGE                6.0
# 2  58647          26          30000                  RENT                5.0
# 3  58648          33          50000                  RENT                4.0
# 4  58649          26         102000              MORTGAGE                8.0
#
#          loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0    HOMEIMPROVEMENT          F      25000          15.76
# 1           PERSONAL          C      10000          12.68
# 2            VENTURE          E       4000          17.19
# 3  DEBTCONSOLIDATION          A       7000           8.90
# 4    HOMEIMPROVEMENT          D      15000          16.32
#
#    loan_percent_income  ... cb_person_cred_hist_length  \
# 0                 0.36  ...                          2
# 1                 0.10  ...                          4
# 2                 0.13  ...                          2
# 3                 0.14  ...                          7
# 4                 0.15  ...                          4
#
#    person_home_ownership_encoded  loan_intent_encoded  loan_grade_encoded  \
# 0                              3                    2                   5
# 1                              0                    4                   2
# 2                              3                    5                   4
# 3                              3                    0                   0
# 4                              0                    2                   3
#
#    cb_person_default_on_file_encoded  xgb_predicted_loan_status  \
# 0                                  0                          1
# 1                                  1                          0
# 2                                  1                          1
# 3                                  0                          0
# 4                                  1                          0
#
#    lgb_predicted_loan_status  log_reg_predicted_loan_status  \
# 0                          1                              1
# 1                          0                              0
# 2                          1                              1
# 3                          0                              0
# 4                          0                              0
#
#    dt_predicted_loan_status  pooled_predicted_loan_status
# 0                         1                             1
# 1                         0                             0
# 2                         0                             1
# 3                         0                             0
# 4                         0                             0
#
# [5 rows x 21 columns]

# %%
df_test[['id', 'pooled_predicted_loan_status']].to_csv('RNNs/Tensorflow-Keras/Binary Classification/Pooled_predictions.csv', index=False)

# %%
# Prepare the dataset for TensorFlow Decision Forests
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(df[features + [label]], label=label)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(df_test[features + ['pooled_predicted_loan_status']], label='pooled_predicted_loan_status')

# Define the tuning function
def objective(trial):
    params = {
        'num_trees': trial.suggest_int('num_trees', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'min_examples': trial.suggest_int('min_examples', 1, 10),
        'sampling_ratio': trial.suggest_uniform('sampling_ratio', 0.6, 1.0)
    }
    
    model = tfdf.keras.GradientBoostedTreesModel(
        num_trees=params['num_trees'],
        max_depth=params['max_depth'],
        min_examples=params['min_examples'],
        sampling_ratio=params['sampling_ratio']
    )
    
    model.compile(metrics=["accuracy"])
    model.fit(train_ds)
    
    evaluation = model.evaluate(test_ds, return_dict=True)
    return evaluation["accuracy"]

# Create the study and optimize
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Get the best parameters
best_params = study.best_params

# Train the final model with the best parameters
final_model = tfdf.keras.GradientBoostedTreesModel(
    num_trees=best_params['num_trees'],
    max_depth=best_params['max_depth'],
    min_examples=best_params['min_examples'],
    sampling_ratio=best_params['sampling_ratio']
)

final_model.compile(metrics=["accuracy"])
final_model.fit(train_ds)

# Make predictions on the test dataset
tfdf_predictions = final_model.predict(test_ds)
df_test['tfdf_predicted_loan_status'] = tfdf_predictions.argmax(axis=1)

# Display the first few rows of the test dataframe to verify the predictions
df_test.head()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729230211.053373 1202413 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1729230211.731015 1202413 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1729230211.731535 1202413 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1729230211.738552 1202413 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1729230211.739006 1202413 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1729230211.739363 1202413 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1729230211.861566 1202413 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1729230211.862185 1202413 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-18 02:43:31.862385: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1729230211.862758 1202413 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-18 02:43:31.862913: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1756 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Ti Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# [I 2024-10-18 02:43:36,083] A new study created in memory with name: no-name-e45adf47-5c02-43a8-acd9-5afa6c241296
# [W 2024-10-18 02:43:36,108] Trial 0 failed with parameters: {'num_trees': 612, 'max_depth': 4, 'min_examples': 4, 'sampling_ratio': 0.6590914767878686} because of the following error: TypeError("GradientBoostedTreesModel.__init__() got an unexpected keyword argument 'sampling_ratio'").
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_1202413/2018729955.py", line 14, in objective
#     model = tfdf.keras.GradientBoostedTreesModel(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow_decision_forests/keras/core.py", line 2310, in wrapper
#     return func(*args, **kargs)
# TypeError: GradientBoostedTreesModel.__init__() got an unexpected keyword argument 'sampling_ratio'
# [W 2024-10-18 02:43:36,383] Trial 0 failed with value None.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 29
#      27 # Create the study and optimize
#      28 study = optuna.create_study(direction='maximize')
# ---> 29 study.optimize(objective, n_trials=50)
#      31 # Get the best parameters
#      32 best_params = study.best_params
#
# File /usr/local/lib/python3.10/dist-packages/optuna/study/study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[12], line 14, in objective(trial)
#       6 def objective(trial):
#       7     params = {
#       8         'num_trees': trial.suggest_int('num_trees', 100, 1000),
#       9         'max_depth': trial.suggest_int('max_depth', 3, 15),
#      10         'min_examples': trial.suggest_int('min_examples', 1, 10),
#      11         'sampling_ratio': trial.suggest_uniform('sampling_ratio', 0.6, 1.0)
#      12     }
# ---> 14     model = tfdf.keras.GradientBoostedTreesModel(
#      15         num_trees=params['num_trees'],
#      16         max_depth=params['max_depth'],
#      17         min_examples=params['min_examples'],
#      18         sampling_ratio=params['sampling_ratio']
#      19     )
#      21     model.compile(metrics=["accuracy"])
#      22     model.fit(train_ds)
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow_decision_forests/keras/core.py:2310, in _list_explicit_arguments.<locals>.wrapper(*args, **kargs)
#    2305 @functools.wraps(func)
#    2306 def wrapper(*args, **kargs):
#    2307   kargs["explicit_args"] = set(
#    2308       list(arguments[: len(args)]) + list(kargs.keys())
#    2309   )
# -> 2310   return func(*args, **kargs)
#
# TypeError: GradientBoostedTreesModel.__init__() got an unexpected keyword argument 'sampling_ratio'

# %%
df_test[['id', 'tfdf_predicted_loan_status']].to_csv('RNNs/Tensorflow-Keras/Binary Classification/TFDF_predictions.csv', index=False)
